# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# Imported required Python libraries.


# NumPy → Numerical calculations.
# Pandas → Data handling & cleaning.
# Matplotlib & Seaborn → Data visualization.

#  Exploratory Data Analysis (EDA) on the ICC Men's ODI World Cup 2023.



# import csv file
# load data set using pandas
# we have 3 datasets load all these 3 datasets

matches=pd.read_csv(r"C:\EDA PROJECT MCA\matches .csv")
deliveries=pd.read_csv(r"C:\EDA PROJECT MCA\deliveries.csv")
points=pd.read_csv(r"C:\EDA PROJECT MCA\points_table.csv")

# basic cleaning/preprocessing for matches dataset

# Basic Data Understanding

print("Initial shape:", matches.shape)
print("First Five rows :",matches.head())
matches.drop_duplicates(inplace=True)
print("Shape after dropping duplicates:", matches.shape)

#check for null values

print("Null values per column:\n", matches.isnull().sum())

print(matches)

# get basic info about dataset
print(matches.columns)
print(matches.info())

# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
print(matches.describe())
# Out:
# Initial shape: (48, 18)
# First Five rows :     season         team1        team2        date  match_number  \
# 0  2023/24       England  New Zealand  2023/10/05             1
# 1  2023/24      Pakistan  Netherlands  2023/10/06             2
# 2  2023/24   Afghanistan   Bangladesh  2023/10/07             3
# 3  2023/24  South Africa    Sri Lanka  2023/10/07             4
# 4  2023/24     Australia        India  2023/10/08             5
#
#                                           venue        city  toss_winner  \
# 0                         Narendra Modi Stadium   Ahmedabad  New Zealand
# 1            Rajiv Gandhi International Stadium   Hyderabad  Netherlands
# 2  Himachal Pradesh Cricket Association Stadium  Dharamsala   Bangladesh
# 3                          Arun Jaitley Stadium       Delhi    Sri Lanka
# 4                        MA Chidambaram Stadium     Chennai    Australia
#
#   toss_decision     player_of_match          umpire1           umpire2  \
# 0         field          R Ravindra  HDPK Dharmasena       Nitin Menon
# 1         field        Saud Shakeel     AT Holdstock          CM Brown
# 2         field  Mehedi Hasan Miraz        JS Wilson   HDPK Dharmasena
# 3         field          AK Markram   RK Illingworth      Sharfuddoula
# 4           bat            KL Rahul      CB Gaffaney  RA Kettleborough
#
#   reserve_umpire  match_referee        winner  winner_runs  winner_wickets  \
# 0   Sharfuddoula      J Srinath   New Zealand          NaN             9.0
# 1     PR Reiffel       JJ Crowe      Pakistan         81.0             NaN
# 2      M Erasmus     AJ Pycroft    Bangladesh          NaN             6.0
# 3       AG Wharf      J Srinath  South Africa        102.0             NaN
# 4   AT Holdstock  RB Richardson         India          NaN             6.0
#
#   match_type
# 0      Group
# 1      Group
# 2      Group
# 3      Group
# 4      Group
# Shape after dropping duplicates: (48, 18)
# Null values per column:
#  season              0
# team1               0
# team2               0
# date                0
# match_number        0
# venue               0
# city                0
# toss_winner         0
# toss_decision       0
# player_of_match     0
# umpire1             0
# umpire2             0
# reserve_umpire      1
# match_referee       0
# winner              0
# winner_runs        24
# winner_wickets     24
# match_type          0
# dtype: int64
#      season         team1         team2        date  match_number  \
# 0   2023/24       England   New Zealand  2023/10/05             1
# 1   2023/24      Pakistan   Netherlands  2023/10/06             2
# 2   2023/24   Afghanistan    Bangladesh  2023/10/07             3
# 3   2023/24  South Africa     Sri Lanka  2023/10/07             4
# 4   2023/24     Australia         India  2023/10/08             5
# 5   2023/24   New Zealand   Netherlands  2023/10/09             6
# 6   2023/24       England    Bangladesh  2023/10/10             7
# 7   2023/24     Sri Lanka      Pakistan  2023/10/10             8
# 8   2023/24   Afghanistan         India  2023/10/11             9
# 9   2023/24  South Africa     Australia  2023/10/12            10
# 10  2023/24    Bangladesh   New Zealand  2023/10/13            11
# 11  2023/24      Pakistan         India  2023/10/14            12
# 12  2023/24   Afghanistan       England  2023/10/15            13
# 13  2023/24     Sri Lanka     Australia  2023/10/16            14
# 14  2023/24   Netherlands  South Africa  2023/10/17            15
# 15  2023/24   New Zealand   Afghanistan  2023/10/18            16
# 16  2023/24    Bangladesh         India  2023/10/19            17
# 17  2023/24     Australia      Pakistan  2023/10/20            18
# 18  2023/24   Netherlands     Sri Lanka  2023/10/21            19
# 19  2023/24  South Africa       England  2023/10/21            20
# 20  2023/24   New Zealand         India  2023/10/22            21
# 21  2023/24      Pakistan   Afghanistan  2023/10/23            22
# 22  2023/24  South Africa    Bangladesh  2023/10/24            23
# 23  2023/24     Australia   Netherlands  2023/10/25            24
# 24  2023/24       England     Sri Lanka  2023/10/26            25
# 25  2023/24      Pakistan  South Africa  2023/10/27            26
# 26  2023/24     Australia   New Zealand  2023/10/28            27
# 27  2023/24   Netherlands    Bangladesh  2023/10/28            28
# 28  2023/24         India       England  2023/10/29            29
# 29  2023/24     Sri Lanka   Afghanistan  2023/10/30            30
# 30  2023/24    Bangladesh      Pakistan  2023/10/31            31
# 31  2023/24  South Africa   New Zealand  2023/11/01            32
# 32  2023/24         India     Sri Lanka  2023/11/02            33
# 33  2023/24   Netherlands   Afghanistan  2023/11/03            34
# 34  2023/24   New Zealand      Pakistan  2023/11/04            35
# 35  2023/24     Australia       England  2023/11/04            36
# 36  2023/24         India  South Africa  2023/11/05            37
# 37  2023/24     Sri Lanka    Bangladesh  2023/11/06            38
# 38  2023/24   Afghanistan     Australia  2023/11/07            39
# 39  2023/24       England   Netherlands  2023/11/08            40
# 40  2023/24     Sri Lanka   New Zealand  2023/11/09            41
# 41  2023/24   Afghanistan  South Africa  2023/11/10            42
# 42  2023/24    Bangladesh     Australia  2023/11/11            43
# 43  2023/24       England      Pakistan  2023/11/11            44
# 44  2023/24         India   Netherlands  2023/11/12            45
# 45  2023/24         India   New Zealand  2023/11/15            46
# 46  2023/24  South Africa     Australia  2023/11/16            47
# 47  2023/24         India     Australia  2023/11/19            48
#
#                                                 venue        city  \
# 0                               Narendra Modi Stadium   Ahmedabad
# 1                  Rajiv Gandhi International Stadium   Hyderabad
# 2        Himachal Pradesh Cricket Association Stadium  Dharamsala
# 3                                Arun Jaitley Stadium       Delhi
# 4                              MA Chidambaram Stadium     Chennai
# 5                  Rajiv Gandhi International Stadium   Hyderabad
# 6        Himachal Pradesh Cricket Association Stadium  Dharamsala
# 7                  Rajiv Gandhi International Stadium   Hyderabad
# 8                                Arun Jaitley Stadium       Delhi
# 9   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...     Lucknow
# 10                             MA Chidambaram Stadium     Chennai
# 11                              Narendra Modi Stadium   Ahmedabad
# 12                               Arun Jaitley Stadium       Delhi
# 13  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...     Lucknow
# 14       Himachal Pradesh Cricket Association Stadium  Dharamsala
# 15                             MA Chidambaram Stadium     Chennai
# 16            Maharashtra Cricket Association Stadium        Pune
# 17                              M Chinnaswamy Stadium   Bengaluru
# 18  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...     Lucknow
# 19                                   Wankhede Stadium      Mumbai
# 20       Himachal Pradesh Cricket Association Stadium  Dharamsala
# 21                             MA Chidambaram Stadium     Chennai
# 22                                   Wankhede Stadium      Mumbai
# 23                               Arun Jaitley Stadium       Delhi
# 24                              M Chinnaswamy Stadium   Bengaluru
# 25                             MA Chidambaram Stadium     Chennai
# 26       Himachal Pradesh Cricket Association Stadium  Dharamsala
# 27                                       Eden Gardens     Kolkata
# 28  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...     Lucknow
# 29            Maharashtra Cricket Association Stadium        Pune
# 30                                       Eden Gardens     Kolkata
# 31            Maharashtra Cricket Association Stadium        Pune
# 32                                   Wankhede Stadium      Mumbai
# 33  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...     Lucknow
# 34                              M Chinnaswamy Stadium   Bengaluru
# 35                              Narendra Modi Stadium   Ahmedabad
# 36                                       Eden Gardens     Kolkata
# 37                               Arun Jaitley Stadium       Delhi
# 38                                   Wankhede Stadium      Mumbai
# 39            Maharashtra Cricket Association Stadium        Pune
# 40                              M Chinnaswamy Stadium   Bengaluru
# 41                              Narendra Modi Stadium   Ahmedabad
# 42            Maharashtra Cricket Association Stadium        Pune
# 43                                       Eden Gardens     Kolkata
# 44                              M Chinnaswamy Stadium   Bengaluru
# 45                                   Wankhede Stadium      Mumbai
# 46                                       Eden Gardens     Kolkata
# 47                              Narendra Modi Stadium   Ahmedabad
#
#      toss_winner toss_decision     player_of_match          umpire1  \
# 0    New Zealand         field          R Ravindra  HDPK Dharmasena
# 1    Netherlands         field        Saud Shakeel     AT Holdstock
# 2     Bangladesh         field  Mehedi Hasan Miraz        JS Wilson
# 3      Sri Lanka         field          AK Markram   RK Illingworth
# 4      Australia           bat            KL Rahul      CB Gaffaney
# 5    Netherlands         field          MJ Santner       PR Reiffel
# 6     Bangladesh         field            DJ Malan       Ahsan Raza
# 7      Sri Lanka           bat     Mohammad Rizwan         AG Wharf
# 8    Afghanistan           bat           RG Sharma         MA Gough
# 9      Australia         field           Q de Kock        JS Wilson
# 10   New Zealand         field         LH Ferguson  HDPK Dharmasena
# 11         India         field           JJ Bumrah        M Erasmus
# 12       England         field    Mujeeb Ur Rahman        RJ Tucker
# 13     Sri Lanka           bat             A Zampa      CB Gaffaney
# 14  South Africa         field          SA Edwards         MA Gough
# 15   Afghanistan         field         GD Phillips        JS Wilson
# 16    Bangladesh           bat             V Kohli     AT Holdstock
# 17      Pakistan         field           DA Warner         CM Brown
# 18   Netherlands           bat    S Samarawickrama       Ahsan Raza
# 19       England         field           H Klaasen  HDPK Dharmasena
# 20         India         field      Mohammed Shami     AT Holdstock
# 21      Pakistan           bat      Ibrahim Zadran       PR Reiffel
# 22  South Africa           bat           Q de Kock       Ahsan Raza
# 23     Australia           bat          GJ Maxwell         MA Gough
# 24       England           bat        CBRLS Kumara     AT Holdstock
# 25      Pakistan           bat            T Shamsi         AG Wharf
# 26   New Zealand         field             TM Head        M Erasmus
# 27   Netherlands           bat     PA van Meekeren        JS Wilson
# 28       England         field           RG Sharma     AT Holdstock
# 29   Afghanistan         field    Fazalhaq Farooqi      CB Gaffaney
# 30    Bangladesh           bat        Fakhar Zaman      Nitin Menon
# 31   New Zealand         field   HE van der Dussen       Ahsan Raza
# 32     Sri Lanka         field      Mohammed Shami         CM Brown
# 33   Netherlands           bat       Mohammad Nabi      Nitin Menon
# 34      Pakistan         field        Fakhar Zaman         P Wilson
# 35       England         field             A Zampa      CB Gaffaney
# 36         India           bat             V Kohli  HDPK Dharmasena
# 37    Bangladesh         field     Shakib Al Hasan        M Erasmus
# 38   Afghanistan           bat          GJ Maxwell         AG Wharf
# 39       England           bat           BA Stokes       Ahsan Raza
# 40   New Zealand         field            TA Boult     AT Holdstock
# 41   Afghanistan           bat   HE van der Dussen         CM Brown
# 42     Australia         field            MR Marsh       Ahsan Raza
# 43       England           bat           DJ Willey         P Wilson
# 44         India           bat             SS Iyer      CB Gaffaney
# 45         India           bat      Mohammed Shami   RK Illingworth
# 46  South Africa           bat             TM Head      Nitin Menon
# 47     Australia         field             TM Head   RK Illingworth
#
#              umpire2         reserve_umpire  match_referee        winner  \
# 0        Nitin Menon           Sharfuddoula      J Srinath   New Zealand
# 1           CM Brown             PR Reiffel       JJ Crowe      Pakistan
# 2    HDPK Dharmasena              M Erasmus     AJ Pycroft    Bangladesh
# 3       Sharfuddoula               AG Wharf      J Srinath  South Africa
# 4   RA Kettleborough           AT Holdstock  RB Richardson         India
# 5          RJ Tucker            Nitin Menon     AJ Pycroft   New Zealand
# 6           P Wilson        HDPK Dharmasena      J Srinath       England
# 7        CB Gaffaney              RJ Tucker     AJ Pycroft      Pakistan
# 8         PR Reiffel           Sharfuddoula       JJ Crowe         India
# 9     RK Illingworth               CM Brown      J Srinath  South Africa
# 10       Nitin Menon               AG Wharf  RB Richardson   New Zealand
# 11    RK Illingworth            CB Gaffaney     AJ Pycroft         India
# 12      Sharfuddoula               P Wilson       JJ Crowe   Afghanistan
# 13         JS Wilson                    NaN  RB Richardson     Australia
# 14  RA Kettleborough             Ahsan Raza       JJ Crowe   Netherlands
# 15          P Wilson          J Madanagopal      J Srinath   New Zealand
# 16  RA Kettleborough              M Erasmus     AJ Pycroft         India
# 17    RK Illingworth          J Madanagopal  RB Richardson     Australia
# 18         M Erasmus            CB Gaffaney       JJ Crowe     Sri Lanka
# 19       Nitin Menon              JS Wilson      J Srinath  South Africa
# 20          MA Gough            Praveen Sen     AJ Pycroft         India
# 21         RJ Tucker        HDPK Dharmasena  RB Richardson   Afghanistan
# 22         JS Wilson  KN Ananthapadmanabhan       JJ Crowe  South Africa
# 23      Sharfuddoula            Nitin Menon     AJ Pycroft     Australia
# 24          CM Brown              RJ Tucker      J Srinath     Sri Lanka
# 25        PR Reiffel       RA Kettleborough  RB Richardson  South Africa
# 26      Sharfuddoula               MA Gough     AJ Pycroft     Australia
# 27          P Wilson            CB Gaffaney       JJ Crowe   Netherlands
# 28         RJ Tucker               CM Brown  RB Richardson         India
# 29    RK Illingworth              M Erasmus      J Srinath   Afghanistan
# 30  RA Kettleborough             PR Reiffel     AJ Pycroft      Pakistan
# 31   HDPK Dharmasena               P Wilson  RB Richardson  South Africa
# 32        PR Reiffel         RK Illingworth       JJ Crowe         India
# 33      Sharfuddoula        HDPK Dharmasena      J Srinath   Afghanistan
# 34  RA Kettleborough              JS Wilson  RB Richardson      Pakistan
# 35         M Erasmus             Ahsan Raza       JJ Crowe     Australia
# 36        PR Reiffel               AG Wharf     AJ Pycroft         India
# 37    RK Illingworth           AT Holdstock  RB Richardson    Bangladesh
# 38          MA Gough           Sharfuddoula       JJ Crowe     Australia
# 39         RJ Tucker               P Wilson     AJ Pycroft       England
# 40         JS Wilson             PR Reiffel      J Srinath   New Zealand
# 41       Nitin Menon            CB Gaffaney       JJ Crowe  South Africa
# 42         M Erasmus       RA Kettleborough     AJ Pycroft     Australia
# 43         RJ Tucker             PR Reiffel      J Srinath       England
# 44          MA Gough               CM Brown  RB Richardson         India
# 45         RJ Tucker           AT Holdstock     AJ Pycroft         India
# 46  RA Kettleborough               MA Gough      J Srinath     Australia
# 47  RA Kettleborough            CB Gaffaney     AJ Pycroft     Australia
#
#     winner_runs  winner_wickets  match_type
# 0           NaN             9.0       Group
# 1          81.0             NaN       Group
# 2           NaN             6.0       Group
# 3         102.0             NaN       Group
# 4           NaN             6.0       Group
# 5          99.0             NaN       Group
# 6         137.0             NaN       Group
# 7           NaN             6.0       Group
# 8           NaN             8.0       Group
# 9         134.0             NaN       Group
# 10          NaN             8.0       Group
# 11          NaN             7.0       Group
# 12         69.0             NaN       Group
# 13          NaN             5.0       Group
# 14         38.0             NaN       Group
# 15        149.0             NaN       Group
# 16          NaN             7.0       Group
# 17         62.0             NaN       Group
# 18          NaN             5.0       Group
# 19        229.0             NaN       Group
# 20          NaN             4.0       Group
# 21          NaN             8.0       Group
# 22        149.0             NaN       Group
# 23        309.0             NaN       Group
# 24          NaN             8.0       Group
# 25          NaN             1.0       Group
# 26          5.0             NaN       Group
# 27         87.0             NaN       Group
# 28        100.0             NaN       Group
# 29          NaN             7.0       Group
# 30          NaN             7.0       Group
# 31        190.0             NaN       Group
# 32        302.0             NaN       Group
# 33          NaN             7.0       Group
# 34         21.0             NaN       Group
# 35         33.0             NaN       Group
# 36        243.0             NaN       Group
# 37          NaN             3.0       Group
# 38          NaN             3.0       Group
# 39        160.0             NaN       Group
# 40          NaN             5.0       Group
# 41          NaN             5.0       Group
# 42          NaN             8.0       Group
# 43         93.0             NaN       Group
# 44        160.0             NaN       Group
# 45         70.0             NaN  Semi Final
# 46          NaN             3.0  Semi Final
# 47          NaN             6.0       Final
# Index(['season', 'team1', 'team2', 'date', 'match_number', 'venue', 'city',
#        'toss_winner', 'toss_decision', 'player_of_match', 'umpire1', 'umpire2',
#        'reserve_umpire', 'match_referee', 'winner', 'winner_runs',
#        'winner_wickets', 'match_type'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           48 non-null     object
#  1   team1            48 non-null     object
#  2   team2            48 non-null     object
#  3   date             48 non-null     object
#  4   match_number     48 non-null     int64
#  5   venue            48 non-null     object
#  6   city             48 non-null     object
#  7   toss_winner      48 non-null     object
#  8   toss_decision    48 non-null     object
#  9   player_of_match  48 non-null     object
#  10  umpire1          48 non-null     object
#  11  umpire2          48 non-null     object
#  12  reserve_umpire   47 non-null     object
#  13  match_referee    48 non-null     object
#  14  winner           48 non-null     object
#  15  winner_runs      24 non-null     float64
#  16  winner_wickets   24 non-null     float64
#  17  match_type       48 non-null     object
# dtypes: float64(2), int64(1), object(15)
# memory usage: 6.9+ KB
# None
#        match_number  winner_runs  winner_wickets
# count         48.00    24.000000       24.000000
# mean          24.50   125.916667        5.916667
# std           14.00    82.242968        2.019829
# min            1.00     5.000000        1.000000
# 25%           12.75    69.750000        5.000000
# 50%           24.50   101.000000        6.000000
# 75%           36.25   160.000000        7.250000
# max           48.00   309.000000        9.000000

# %%
# basic cleaning/preprocessing for deliveries dataset

# Basic Data Understanding

print("Initial shape:", deliveries.shape)
print("First Five rows :",deliveries.head())
deliveries.drop_duplicates(inplace=True)
print("Shape after dropping duplicates:", deliveries.shape)

#check for null values

print("Null values per column:\n", deliveries.isnull().sum())

print(deliveries)

# get basic info about dataset
print(deliveries.columns)
print(deliveries.info())

# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
print(deliveries.describe())
# Out:
# Initial shape: (26119, 22)
# First Five rows :    match_id   season  start_date                             venue  innings  \
# 0         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
# 1         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
# 2         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
# 3         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
# 4         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
#
#    ball batting_team bowling_team      striker  non_striker  ... extras  \
# 0   0.1      England  New Zealand  JM Bairstow     DJ Malan  ...      0
# 1   0.2      England  New Zealand  JM Bairstow     DJ Malan  ...      0
# 2   0.3      England  New Zealand  JM Bairstow     DJ Malan  ...      0
# 3   0.4      England  New Zealand     DJ Malan  JM Bairstow  ...      0
# 4   0.5      England  New Zealand  JM Bairstow     DJ Malan  ...      0
#
#    wides  noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# 0    NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 1    NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 2    NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 3    NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 4    NaN      NaN   NaN      NaN      NaN          NaN               NaN
#
#   other_wicket_type other_player_dismissed
# 0               NaN                    NaN
# 1               NaN                    NaN
# 2               NaN                    NaN
# 3               NaN                    NaN
# 4               NaN                    NaN
#
# [5 rows x 22 columns]
# Shape after dropping duplicates: (26118, 22)
# Null values per column:
#  match_id                      0
# season                        0
# start_date                    0
# venue                         0
# innings                       0
# ball                          0
# batting_team                  0
# bowling_team                  0
# striker                       0
# non_striker                   0
# bowler                        0
# runs_off_bat                  0
# extras                        0
# wides                     25453
# noballs                   26062
# byes                      26080
# legbyes                   25925
# penalty                   26117
# wicket_type               25389
# player_dismissed          25389
# other_wicket_type         26117
# other_player_dismissed    26117
# dtype: int64
#        match_id   season  start_date                             venue  \
# 0             1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad
# 1             1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad
# 2             1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad
# 3             1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad
# 4             1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad
# ...         ...      ...         ...                               ...
# 26114        45  2023/24  2023-11-12  M Chinnaswamy Stadium, Bengaluru
# 26115        45  2023/24  2023-11-12  M Chinnaswamy Stadium, Bengaluru
# 26116        45  2023/24  2023-11-12  M Chinnaswamy Stadium, Bengaluru
# 26117        45  2023/24  2023-11-12  M Chinnaswamy Stadium, Bengaluru
# 26118        45  2023/24  2023-11-12  M Chinnaswamy Stadium, Bengaluru
#
#        innings  ball batting_team bowling_team          striker  \
# 0            1   0.1      England  New Zealand      JM Bairstow
# 1            1   0.2      England  New Zealand      JM Bairstow
# 2            1   0.3      England  New Zealand      JM Bairstow
# 3            1   0.4      England  New Zealand         DJ Malan
# 4            1   0.5      England  New Zealand      JM Bairstow
# ...        ...   ...          ...          ...              ...
# 26114        2  47.1  Netherlands        India  PA van Meekeren
# 26115        2  47.2  Netherlands        India  PA van Meekeren
# 26116        2  47.3  Netherlands        India    AT Nidamanuru
# 26117        2  47.4  Netherlands        India    AT Nidamanuru
# 26118        2  47.5  Netherlands        India    AT Nidamanuru
#
#            non_striker  ... extras  wides  noballs  byes  legbyes  penalty  \
# 0             DJ Malan  ...      0    NaN      NaN   NaN      NaN      NaN
# 1             DJ Malan  ...      0    NaN      NaN   NaN      NaN      NaN
# 2             DJ Malan  ...      0    NaN      NaN   NaN      NaN      NaN
# 3          JM Bairstow  ...      0    NaN      NaN   NaN      NaN      NaN
# 4             DJ Malan  ...      0    NaN      NaN   NaN      NaN      NaN
# ...                ...  ...    ...    ...      ...   ...      ...      ...
# 26114    AT Nidamanuru  ...      0    NaN      NaN   NaN      NaN      NaN
# 26115    AT Nidamanuru  ...      0    NaN      NaN   NaN      NaN      NaN
# 26116  PA van Meekeren  ...      0    NaN      NaN   NaN      NaN      NaN
# 26117  PA van Meekeren  ...      0    NaN      NaN   NaN      NaN      NaN
# 26118  PA van Meekeren  ...      0    NaN      NaN   NaN      NaN      NaN
#
#        wicket_type  player_dismissed other_wicket_type other_player_dismissed
# 0              NaN               NaN               NaN                    NaN
# 1              NaN               NaN               NaN                    NaN
# 2              NaN               NaN               NaN                    NaN
# 3              NaN               NaN               NaN                    NaN
# 4              NaN               NaN               NaN                    NaN
# ...            ...               ...               ...                    ...
# 26114          NaN               NaN               NaN                    NaN
# 26115          NaN               NaN               NaN                    NaN
# 26116          NaN               NaN               NaN                    NaN
# 26117          NaN               NaN               NaN                    NaN
# 26118       caught     AT Nidamanuru               NaN                    NaN
#
# [26118 rows x 22 columns]
# Index(['match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes',
#        'penalty', 'wicket_type', 'player_dismissed', 'other_wicket_type',
#        'other_player_dismissed'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 26118 entries, 0 to 26118
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   match_id                26118 non-null  int64
#  1   season                  26118 non-null  object
#  2   start_date              26118 non-null  object
#  3   venue                   26118 non-null  object
#  4   innings                 26118 non-null  int64
#  5   ball                    26118 non-null  float64
#  6   batting_team            26118 non-null  object
#  7   bowling_team            26118 non-null  object
#  8   striker                 26118 non-null  object
#  9   non_striker             26118 non-null  object
#  10  bowler                  26118 non-null  object
#  11  runs_off_bat            26118 non-null  int64
#  12  extras                  26118 non-null  int64
#  13  wides                   665 non-null    float64
#  14  noballs                 56 non-null     float64
#  15  byes                    38 non-null     float64
#  16  legbyes                 193 non-null    float64
#  17  penalty                 1 non-null      float64
#  18  wicket_type             729 non-null    object
#  19  player_dismissed        729 non-null    object
#  20  other_wicket_type       1 non-null      object
#  21  other_player_dismissed  1 non-null      object
# dtypes: float64(6), int64(4), object(12)
# memory usage: 4.6+ MB
# None
#            match_id       innings          ball  runs_off_bat        extras  \
# count  26118.000000  26118.000000  26118.000000  26118.000000  26118.000000
# mean      24.586645      1.448886     22.648009      0.896968      0.046405
# std       13.996963      0.497390     13.742183      1.399978      0.293629
# min        1.000000      1.000000      0.100000      0.000000      0.000000
# 25%       12.000000      1.000000     10.600000      0.000000      0.000000
# 50%       24.000000      1.000000     22.100000      0.000000      0.000000
# 75%       37.000000      2.000000     34.100000      1.000000      0.000000
# max       48.000000      2.000000     49.900000      6.000000      5.000000
#
#             wides  noballs       byes     legbyes  penalty
# count  665.000000     56.0  38.000000  193.000000      1.0
# mean     1.218045      1.0   2.342105    1.305699      5.0
# std      0.853222      0.0   1.475499    0.850746      NaN
# min      1.000000      1.0   1.000000    1.000000      5.0
# 25%      1.000000      1.0   1.000000    1.000000      5.0
# 50%      1.000000      1.0   1.000000    1.000000      5.0
# 75%      1.000000      1.0   4.000000    1.000000      5.0
# max      5.000000      1.0   4.000000    4.000000      5.0

# %%
# basic cleaning/preprocessing for points_table dataset

# Basic Data Understanding

print("Initial shape:", points.shape)
print("First Five rows :",points.head())
points.drop_duplicates(inplace=True)
print("Shape after dropping duplicates:", points.shape)

#check for null values

print("Null values per column:\n", points.isnull().sum())

print(points)

# get basic info about dataset
print(points.columns)
print(points.info())

# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
print(points.describe())
# Out:
# Initial shape: (10, 11)
# First Five rows :    Ranking          Team  Matches  Won  Lost  Tie  No Results  Points  \
# 0        1         India        9    9     0    0           0      18
# 1        2  South Africa        9    7     2    0           0      14
# 2        3     Australia        9    7     2    0           0      14
# 3        4   New Zealand        9    5     4    0           0      10
# 4        5      Pakistan        9    4     5    0           0       8
#
#    Net Run Rate         For     Against
# 0         2.570  2523/396.2  1708/450.0
# 1         1.261  2685/437.5  2158/443.0
# 2         0.841  2631/426.5  2349/441.2
# 3         0.743  2315/378.0  2279/423.3
# 4        -0.199  2328/406.2  2385/402.2
# Shape after dropping duplicates: (10, 11)
# Null values per column:
#  Ranking         0
# Team            0
# Matches         0
# Won             0
# Lost            0
# Tie             0
# No Results      0
# Points          0
# Net Run Rate    0
# For             0
# Against         0
# dtype: int64
#    Ranking          Team  Matches  Won  Lost  Tie  No Results  Points  \
# 0        1         India        9    9     0    0           0      18
# 1        2  South Africa        9    7     2    0           0      14
# 2        3     Australia        9    7     2    0           0      14
# 3        4   New Zealand        9    5     4    0           0      10
# 4        5      Pakistan        9    4     5    0           0       8
# 5        6   Afghanistan        9    4     5    0           0       8
# 6        7       England        9    3     6    0           0       6
# 7        8    Bangladesh        9    2     7    0           0       4
# 8        9     Sri Lanka        9    2     7    0           0       4
# 9       10   Netherlands        9    2     7    0           0       4
#
#    Net Run Rate         For     Against
# 0         2.570  2523/396.2  1708/450.0
# 1         1.261  2685/437.5  2158/443.0
# 2         0.841  2631/426.5  2349/441.2
# 3         0.743  2315/378.0  2279/423.3
# 4        -0.199  2328/406.2  2385/402.2
# 5        -0.336  2095/425.5  2176/414.0
# 6        -0.572  2245/450.0  2291/412.0
# 7        -1.087  2053/425.5  2431/411.3
# 8        -1.419  2048/424.0  2459/393.3
# 9        -1.825  1862/443.0  2549/422.5
# Index(['Ranking', 'Team', 'Matches', 'Won', 'Lost', 'Tie', 'No Results',
#        'Points', 'Net Run Rate', 'For', 'Against'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ranking       10 non-null     int64
#  1   Team          10 non-null     object
#  2   Matches       10 non-null     int64
#  3   Won           10 non-null     int64
#  4   Lost          10 non-null     int64
#  5   Tie           10 non-null     int64
#  6   No Results    10 non-null     int64
#  7   Points        10 non-null     int64
#  8   Net Run Rate  10 non-null     float64
#  9   For           10 non-null     object
#  10  Against       10 non-null     object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 1012.0+ bytes
# None
#         Ranking  Matches        Won       Lost   Tie  No Results     Points  \
# count  10.00000     10.0  10.000000  10.000000  10.0        10.0  10.000000
# mean    5.50000      9.0   4.500000   4.500000   0.0         0.0   9.000000
# std     3.02765      0.0   2.460804   2.460804   0.0         0.0   4.921608
# min     1.00000      9.0   2.000000   0.000000   0.0         0.0   4.000000
# 25%     3.25000      9.0   2.250000   2.500000   0.0         0.0   4.500000
# 50%     5.50000      9.0   4.000000   5.000000   0.0         0.0   8.000000
# 75%     7.75000      9.0   6.500000   6.750000   0.0         0.0  13.000000
# max    10.00000      9.0   9.000000   7.000000   0.0         0.0  18.000000
#
#        Net Run Rate
# count     10.000000
# mean      -0.002300
# std        1.352353
# min       -1.825000
# 25%       -0.958250
# 50%       -0.267500
# 75%        0.816500
# max        2.570000

# %%
# Exploratory Data Analysis (EDA)

# tournament stats (Total runs, Wickets, Boundaries)

total_runs = deliveries["runs_off_bat"].sum() + deliveries["extras"].sum()

print("Total Runs Scored In Tournament: ", total_runs, "Out Of which ",deliveries["extras"].sum()," Runs Are Extra")

bat_runs = deliveries["runs_off_bat"].sum()
extras = deliveries["extras"].sum()

plt.pie([bat_runs, extras],
        labels=["Runs from Bat", "Extras"],
        autopct="%1.1f%%")

plt.title("Runs Distribution")
plt.show()


# Total Wickets In Tournament

total_wickets = deliveries["wicket_type"].notna().sum()

print("Total Wickets In Tournament :", total_wickets)


wicket_counts = deliveries["wicket_type"].value_counts()

print(wicket_counts)


plt.figure(figsize=(10,6))

plt.bar(wicket_counts.index, wicket_counts.values)

plt.title("Wicket Types Distribution")
plt.xlabel("Wicket Type")
plt.ylabel("Number of Wickets")

plt.xticks(rotation=45)

plt.show()

print("This Plot Shows That Maximum Wickets Falls Through Caught.")

#total boundaries in tournament

# count fours
fours = (deliveries["runs_off_bat"] == 4).sum()

# count sixes
sixes = (deliveries["runs_off_bat"] == 6).sum()

# total boundaries
total_boundaries = fours + sixes

print("Total Fours:", fours)
print("Total Sixes:", sixes)
print("Total Boundaries:", total_boundaries)

labels = ["Fours", "Sixes"]
values = [fours, sixes]

plt.figure(figsize=(7,7))

plt.pie(values, labels=labels, autopct="%1.1f%%", startangle=90)

plt.title("Boundaries Distribution")

plt.show()

print("Pie chart will show 4s dominate over 6s")
# Out:
# Total Runs Scored In Tournament:  24639 Out Of which  1212  Runs Are Extra
# Total Wickets In Tournament : 729
# wicket_type
# caught               448
# bowled               141
# lbw                   76
# run out               38
# caught and bowled     14
# stumped               11
# retired hurt           1
# Name: count, dtype: int64
# This Plot Shows That Maximum Wickets Falls Through Caught.
# Total Fours: 2241
# Total Sixes: 644
# Total Boundaries: 2885
# Pie chart will show 4s dominate over 6s

# %%
# calculate total runs per batsman
top_batsmen = deliveries.groupby("striker")["runs_off_bat"].sum()

print(top_batsmen)

# sort and get top 10
top10 = top_batsmen.sort_values(ascending=False).head(10)

print(top10)

plt.figure(figsize=(10,6))

plt.bar(top10.index, top10.values)

plt.title("Top 10 Run Scorers - ICC World Cup 2023")
plt.xlabel("Batsman")
plt.ylabel("Total Runs")

plt.xticks(rotation=45)

plt.show()

print("The analysis shows the top performing batsmen of the tournament. Players like Virat Kohli and Rohit Sharma dominated the run charts, indicating strong batting performance during the World Cup.")



#Top 10 Wicket Takers

# filter rows where wicket occurred
wickets = deliveries[(deliveries["wicket_type"].notna()) & (deliveries["wicket_type"] != "run out")]

# count wickets by bowler
top_bowlers = wickets.groupby("bowler").size()

# sort and get top 10
top10_bowlers = top_bowlers.sort_values(ascending=False).head(10)

print(top10_bowlers)


plt.figure(figsize=(10,6))

plt.bar(top10_bowlers.index, top10_bowlers.values)

plt.title("Top 10 Highest Wicket Takers - ICC World Cup 2023")
plt.xlabel("Bowler")
plt.ylabel("Wickets")

plt.xticks(rotation=45)

plt.show()

print("The analysis identifies the most successful bowlers of the ICC World Cup 2023. Bowlers like Mohammed Shami and Adam Zampa dominated the tournament with the highest wicket counts, showing their major impact on match outcomes.")
# Out:
# striker
# A Dutt              70
# A Zampa             48
# AAP Atkinson        37
# AD Mathews          51
# AK Markram         406
#                   ...
# Usama Mir            0
# V Kohli            765
# Vikramjit Singh     98
# W Barresi           83
# WA Young           206
# Name: runs_off_bat, Length: 146, dtype: int64
# striker
# V Kohli              765
# RG Sharma            597
# Q de Kock            594
# R Ravindra           578
# DJ Mitchell          552
# DA Warner            535
# SS Iyer              530
# KL Rahul             452
# HE van der Dussen    448
# MR Marsh             441
# Name: runs_off_bat, dtype: int64
# The analysis shows the top performing batsmen of the tournament. Players like Virat Kohli and Rohit Sharma dominated the run charts, indicating strong batting performance during the World Cup.
# bowler
# Mohammed Shami         24
# A Zampa                23
# D Madushanka           21
# G Coetzee              20
# JJ Bumrah              20
# Shaheen Shah Afridi    18
# M Jansen               17
# Haris Rauf             16
# BFW de Leede           16
# RA Jadeja              16
# dtype: int64
# The analysis identifies the most successful bowlers of the ICC World Cup 2023. Bowlers like Mohammed Shami and Adam Zampa dominated the tournament with the highest wicket counts, showing their major impact on match outcomes.

# %%
#Best Striker of the Ball (Top Batsmen by Strike Rate)

#strike_rate = (runs / balls) * 100

import pandas as pd

runs = deliveries.groupby("striker")["runs_off_bat"].sum()
balls = deliveries.groupby("striker").size()

strike_rate = (runs / balls) * 100

sr_df = pd.DataFrame({
    "Runs": runs,
    "Balls": balls,
    "Strike Rate": strike_rate
})

print("Sometimes players who faced very few balls get very high strike rate So filter players who faced at least 100 balls.")
sr_df = sr_df[sr_df["Balls"] >= 100]
top_sr = sr_df.sort_values("Strike Rate", ascending=False).head(10)

print(top_sr)



top_sr["Strike Rate"].plot(kind="bar", figsize=(10,6))

plt.title("Top 10 Batsmen by Strike Rate")
plt.xlabel("Batsman")
plt.ylabel("Strike Rate")

plt.show()
# Out:
# Sometimes players who faced very few balls get very high strike rate So filter players who faced at least 100 balls.
#                 Runs  Balls  Strike Rate
# striker
# GJ Maxwell       400    271   147.601476
# H Klaasen        373    287   129.965157
# TM Head          329    261   126.053640
# RG Sharma        597    485   123.092784
# Fakhar Zaman     220    182   120.879121
# HC Brook         169    151   111.920530
# Iftikhar Ahmed   142    129   110.077519
# BKG Mendis       294    269   109.293680
# SS Iyer          530    485   109.278351
# DJ Mitchell      552    510   108.235294

# %%
deliveries["over"] = deliveries["ball"].astype(int)

def phase(over):
    if over <= 10:
        return "Powerplay"
    elif over <= 40:
        return "Middle Overs"
    else:
        return "Death Overs"

deliveries["phase"] = deliveries["over"].apply(phase)


runs_phase = deliveries.groupby("phase")["runs_off_bat"].sum()

print(runs_phase)


plt.figure(figsize=(8,6))

plt.bar(runs_phase.index, runs_phase.values)

plt.title("Run Distribution Across Match Phases")
plt.xlabel("Match Phase")
plt.ylabel("Runs")

plt.show()

wickets_phase = deliveries[deliveries["wicket_type"].notna()].groupby("phase").size()
print(wickets_phase)

wickets_phase.plot(kind="bar")

plt.title("Wickets in Each Phase")
plt.xlabel("Match Phase")
plt.ylabel("wickets")

plt.show()


balls_phase = deliveries.groupby("phase").size()
print(balls_phase)

overs_phase = balls_phase / 6

run_rate = runs_phase / overs_phase

print(run_rate)

run_rate.plot(kind="bar", figsize=(8,6))

plt.title("Run Rate by Match Phase")
plt.xlabel("Match Phase")
plt.ylabel("Run Rate")

plt.show()



print("The phase-wise analysis shows how teams scored runs during different stages of the match. Most runs were scored during the middle overs, where batsmen focused on building partnerships. The death overs phase showed aggressive batting with higher scoring rates, while the powerplay provided early scoring opportunities due to field restrictions.")
print("Run rate analysis shows that scoring acceleration occurs during the Death Overs, where batsmen play aggressively to maximize runs. The Powerplay provides a steady start due to field restrictions, while the Middle Overs focus on strike rotation and partnership building. Therefore, teams that maintained a high run rate during the middle and death overs had a higher probability of winning matches.")
# Out:
# phase
# Death Overs      3753
# Middle Overs    14224
# Powerplay        5450
# Name: runs_off_bat, dtype: int64
# phase
# Death Overs     188
# Middle Overs    383
# Powerplay       158
# dtype: int64
# phase
# Death Overs      3178
# Middle Overs    16396
# Powerplay        6544
# dtype: int64
# phase
# Death Overs     7.085588
# Middle Overs    5.205172
# Powerplay       4.996944
# dtype: float64
# The phase-wise analysis shows how teams scored runs during different stages of the match. Most runs were scored during the middle overs, where batsmen focused on building partnerships. The death overs phase showed aggressive batting with higher scoring rates, while the powerplay provided early scoring opportunities due to field restrictions.
# Run rate analysis shows that scoring acceleration occurs during the Death Overs, where batsmen play aggressively to maximize runs. The Powerplay provides a steady start due to field restrictions, while the Middle Overs focus on strike rotation and partnership building. Therefore, teams that maintained a high run rate during the middle and death overs had a higher probability of winning matches.

# %%
# check if toss winner also won the match
matches["toss_win_match_win"] = matches["toss_winner"] == matches["winner"]

print(matches[["toss_winner","winner","toss_win_match_win"]])


toss_result = matches["toss_win_match_win"].value_counts()

print(toss_result)



toss_result.plot(kind="bar")

plt.title("Impact of Toss on Match Result")
plt.xlabel("Toss Winner Also Won Match")
plt.ylabel("Number of Matches")

plt.xticks([0,1], ["Lost After Winning Toss","Won After Winning Toss"], rotation=0)

plt.show()

print("The analysis shows that winning the toss did not provide a significant advantage in the ICC Men's ODI World Cup 2023. In fact, teams that won the toss lost more matches (60.4%) than they won (39.6%). This indicates that match outcomes were more strongly influenced by team performance, batting strength, bowling strategy, and match conditions, rather than the toss decision itself.")
# Out:
#      toss_winner        winner  toss_win_match_win
# 0    New Zealand   New Zealand                True
# 1    Netherlands      Pakistan               False
# 2     Bangladesh    Bangladesh                True
# 3      Sri Lanka  South Africa               False
# 4      Australia         India               False
# 5    Netherlands   New Zealand               False
# 6     Bangladesh       England               False
# 7      Sri Lanka      Pakistan               False
# 8    Afghanistan         India               False
# 9      Australia  South Africa               False
# 10   New Zealand   New Zealand                True
# 11         India         India                True
# 12       England   Afghanistan               False
# 13     Sri Lanka     Australia               False
# 14  South Africa   Netherlands               False
# 15   Afghanistan   New Zealand               False
# 16    Bangladesh         India               False
# 17      Pakistan     Australia               False
# 18   Netherlands     Sri Lanka               False
# 19       England  South Africa               False
# 20         India         India                True
# 21      Pakistan   Afghanistan               False
# 22  South Africa  South Africa                True
# 23     Australia     Australia                True
# 24       England     Sri Lanka               False
# 25      Pakistan  South Africa               False
# 26   New Zealand     Australia               False
# 27   Netherlands   Netherlands                True
# 28       England         India               False
# 29   Afghanistan   Afghanistan                True
# 30    Bangladesh      Pakistan               False
# 31   New Zealand  South Africa               False
# 32     Sri Lanka         India               False
# 33   Netherlands   Afghanistan               False
# 34      Pakistan      Pakistan                True
# 35       England     Australia               False
# 36         India         India                True
# 37    Bangladesh    Bangladesh                True
# 38   Afghanistan     Australia               False
# 39       England       England                True
# 40   New Zealand   New Zealand                True
# 41   Afghanistan  South Africa               False
# 42     Australia     Australia                True
# 43       England       England                True
# 44         India         India                True
# 45         India         India                True
# 46  South Africa     Australia               False
# 47     Australia     Australia                True
# toss_win_match_win
# False    29
# True     19
# Name: count, dtype: int64
# The analysis shows that winning the toss did not provide a significant advantage in the ICC Men's ODI World Cup 2023. In fact, teams that won the toss lost more matches (60.4%) than they won (39.6%). This indicates that match outcomes were more strongly influenced by team performance, batting strength, bowling strategy, and match conditions, rather than the toss decision itself.

# %%
# Venue Stats: Pitch behavior across different stadiums in India.

import pandas as pd

df = pd.read_csv("deliveries.csv")

df["total_runs"] = df["runs_off_bat"] + df["extras"]

venue_runs = df.groupby("venue")["total_runs"].sum()

print(venue_runs.sort_values(ascending=False))



venue_runs.sort_values(ascending=False).plot(kind="bar", figsize=(12,6))

plt.title("Total Runs by Venue")
plt.xlabel("Venue")
plt.ylabel("Runs")

plt.show()

print("Wankhede Stadium recorded the highest total runs, indicating a batting-friendly pitch. The ground is known for short boundaries and good bounce, which helps batsmen score freely.")


venue_wickets = df[df["wicket_type"].notna()].groupby("venue").size()

print(venue_wickets.sort_values(ascending=False))


venue_wickets.sort_values(ascending=False).plot(kind="bar", figsize=(12,6))

plt.title("Wickets by Venue")
plt.xlabel("Venue")
plt.ylabel("Number of Wickets")

plt.show()

print("Despite high runs, Dharamsala also produced the highest number of wickets, indicating a balanced pitch where both batsmen and bowlers had opportunities.")


print("The venue analysis shows that pitch behavior varied significantly across stadiums. Some venues like Wankhede and Delhi favored batting, while others like Dharamsala offered a balanced contest between bat and ball. These variations highlight how pitch conditions and ground dimensions influence match strategies and outcomes.")
# Out:
# venue
# Wankhede Stadium, Mumbai                                                 2904
# Arun Jaitley Stadium, Delhi                                              2848
# Himachal Pradesh Cricket Association Stadium, Dharamsala                 2675
# Maharashtra Cricket Association Stadium, Pune                            2655
# M Chinnaswamy Stadium, Bengaluru                                         2592
# Narendra Modi Stadium, Ahmedabad                                         2459
# MA Chidambaram Stadium, Chepauk, Chennai                                 2429
# Eden Gardens, Kolkata                                                    2197
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow    2155
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                     1725
# Name: total_runs, dtype: int64
# Wankhede Stadium recorded the highest total runs, indicating a batting-friendly pitch. The ground is known for short boundaries and good bounce, which helps batsmen score freely.
# venue
# Himachal Pradesh Cricket Association Stadium, Dharamsala                 86
# Eden Gardens, Kolkata                                                    84
# Arun Jaitley Stadium, Delhi                                              79
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow    79
# Wankhede Stadium, Mumbai                                                 75
# Narendra Modi Stadium, Ahmedabad                                         72
# MA Chidambaram Stadium, Chepauk, Chennai                                 70
# M Chinnaswamy Stadium, Bengaluru                                         67
# Maharashtra Cricket Association Stadium, Pune                            67
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                     50
# dtype: int64
# Despite high runs, Dharamsala also produced the highest number of wickets, indicating a balanced pitch where both batsmen and bowlers had opportunities.
# The venue analysis shows that pitch behavior varied significantly across stadiums. Some venues like Wankhede and Delhi favored batting, while others like Dharamsala offered a balanced contest between bat and ball. These variations highlight how pitch conditions and ground dimensions influence match strategies and outcomes.

# %%
# most player of the match award

pom_counts=matches["player_of_match"].value_counts()

print(pom_counts)

most_pom_player = pom_counts.idxmax()
most_pom_count = pom_counts.max()
print("The player with the most 'Man of the Match', awards is: ",most_pom_player ,"with ",most_pom_count ,"times.")

plt.figure(figsize=(10, 6))
sns.barplot(x=pom_counts.values, y=pom_counts.index,  hue=pom_counts.index, legend=False,palette='viridis')
plt.title('Top Player of the Match Winners - ICC World Cup 2023')
plt.xlabel('Number of Awards')
plt.ylabel('Player Name')
plt.tight_layout()
print("This indicates that match-winning performances were delivered by different players in different matches rather than relying on a single individual. In particular, Australia’s success can be attributed to contributions from multiple players like Travis Head, Glenn Maxwell, and Adam Zampa, who played crucial roles with both bat and ball in important matches. Such distributed performances highlight the depth and balance of the team, which ultimately helped Australia perform consistently and win the tournament.")



toss_win = matches["toss_winner"].value_counts()

print(toss_win)

plt.figure(figsize=(10,6))

sns.barplot(x=toss_win.values, y=toss_win.index, palette="viridis")

plt.title("Most Toss Wins - ICC World Cup 2023")
plt.xlabel("Toss Wins")
plt.ylabel("Team Name")

plt.tight_layout()
plt.show()

print("Team with most toss wins:", toss_win.idxmax())
print("Winning the toss did not guarantee match victory.")
# Out:
# player_of_match
# Mohammed Shami        3
# TM Head               3
# RG Sharma             2
# GJ Maxwell            2
# V Kohli               2
# A Zampa               2
# Fakhar Zaman          2
# Q de Kock             2
# HE van der Dussen     2
# Mohammad Nabi         1
# Ibrahim Zadran        1
# Shakib Al Hasan       1
# Fazalhaq Farooqi      1
# BA Stokes             1
# PA van Meekeren       1
# TA Boult              1
# MR Marsh              1
# T Shamsi              1
# CBRLS Kumara          1
# DJ Willey             1
# R Ravindra            1
# S Samarawickrama      1
# H Klaasen             1
# Saud Shakeel          1
# DA Warner             1
# GD Phillips           1
# SA Edwards            1
# Mujeeb Ur Rahman      1
# JJ Bumrah             1
# LH Ferguson           1
# Mohammad Rizwan       1
# DJ Malan              1
# MJ Santner            1
# KL Rahul              1
# AK Markram            1
# Mehedi Hasan Miraz    1
# SS Iyer               1
# Name: count, dtype: int64
# The player with the most 'Man of the Match', awards is:  Mohammed Shami with  3 times.
# This indicates that match-winning performances were delivered by different players in different matches rather than relying on a single individual. In particular, Australia’s success can be attributed to contributions from multiple players like Travis Head, Glenn Maxwell, and Adam Zampa, who played crucial roles with both bat and ball in important matches. Such distributed performances highlight the depth and balance of the team, which ultimately helped Australia perform consistently and win the tournament.
# toss_winner
# England         7
# New Zealand     5
# Netherlands     5
# Bangladesh      5
# Australia       5
# Afghanistan     5
# India           5
# Sri Lanka       4
# Pakistan        4
# South Africa    3
# Name: count, dtype: int64
# C:\Users\niles\AppData\Local\Temp\ipykernel_30964\4260341965.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=toss_win.values, y=toss_win.index, palette="viridis")
# Team with most toss wins: England
# Winning the toss did not guarantee match victory.

# %%
# Fill NaN with 0 for easy comparison
matches['winner_runs'] = matches['winner_runs'].fillna(0)
matches['winner_wickets'] = matches['winner_wickets'].fillna(0)


bat_first_wins = matches[matches['winner_runs'] > 0].shape[0]
bowl_first_wins = matches[matches['winner_wickets'] > 0].shape[0] 


print(f"--- Match Outcome Analysis ---")
print(f"Matches Won by Batting First (Defending): {bat_first_wins}")
print(f"Matches Won by Bowling First (Chasing):  {bowl_first_wins}")

print("The match outcome analysis shows that teams won an equal number of matches when batting first and when chasing. This indicates that there was no clear advantage for either batting first or chasing during the ICC Men's ODI World Cup 2023. The results suggest that team performance, strategy, and match conditions had a greater influence on match outcomes than the choice of batting or bowling first.")
labels = ["Bat First (Defending)", "Chasing (Bowling First)"]
values = [bat_first_wins, bowl_first_wins]

plt.figure(figsize=(6,6))

plt.pie(values, labels=labels, autopct="%1.1f%%", startangle=90)

plt.title("Bat First vs Chasing Wins - ICC World Cup 2023")

plt.show()
# Out:
# --- Match Outcome Analysis ---
# Matches Won by Batting First (Defending): 24
# Matches Won by Bowling First (Chasing):  24
# The match outcome analysis shows that teams won an equal number of matches when batting first and when chasing. This indicates that there was no clear advantage for either batting first or chasing during the ICC Men's ODI World Cup 2023. The results suggest that team performance, strategy, and match conditions had a greater influence on match outcomes than the choice of batting or bowling first.

# %%
points = pd.read_csv("points_table.csv")

plt.figure(figsize=(10,6))
sns.barplot(x="Points", y="Team", data=points, palette="viridis")

plt.title("Points Earned by Teams - ICC World Cup 2023")
plt.xlabel("Points")
plt.ylabel("Team")

plt.show()

print("Teams with higher points finished higher in the tournament ranking.")



plt.figure(figsize=(10,6))
sns.barplot(x="Won", y="Team", data=points, palette="coolwarm")

plt.title("Matches Won by Each Team")
plt.xlabel("Matches Won")
plt.ylabel("Team")

plt.show()

print("his shows which teams performed best during the group stage.")



plt.figure(figsize=(10,6))
sns.barplot(x="Net Run Rate", y="Team", data=points, palette="magma")

plt.title("Net Run Rate Comparison")
plt.xlabel("Net Run Rate")
plt.ylabel("Team")

plt.show()

print("Net Run Rate shows how dominant a team was in scoring and restricting runs.")



points["Win %"] = (points["Won"] / points["Matches"]) * 100

print(points[["Team","Win %"]])

sns.barplot(x="Win %", y="Team", data=points, palette="viridis")

plt.title("Win Percentage by Team")
plt.xlabel("Win Percentage")

plt.show()

print("Shows consistency of each team.")
# Out:
# C:\Users\niles\AppData\Local\Temp\ipykernel_30964\1013141649.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Points", y="Team", data=points, palette="viridis")
# C:\Users\niles\AppData\Local\Temp\ipykernel_30964\1013141649.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Won", y="Team", data=points, palette="coolwarm")
# Teams with higher points finished higher in the tournament ranking.
# his shows which teams performed best during the group stage.
# C:\Users\niles\AppData\Local\Temp\ipykernel_30964\1013141649.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Net Run Rate", y="Team", data=points, palette="magma")
# Net Run Rate shows how dominant a team was in scoring and restricting runs.
#            Team       Win %
# 0         India  100.000000
# 1  South Africa   77.777778
# 2     Australia   77.777778
# 3   New Zealand   55.555556
# 4      Pakistan   44.444444
# 5   Afghanistan   44.444444
# 6       England   33.333333
# 7    Bangladesh   22.222222
# 8     Sri Lanka   22.222222
# 9   Netherlands   22.222222
# C:\Users\niles\AppData\Local\Temp\ipykernel_30964\1013141649.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Win %", y="Team", data=points, palette="viridis")
# Shows consistency of each team.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("deliveries.csv")

# filter wickets
wickets = df[df["wicket_type"].notna()].copy()

# Spinner list (World Cup 2023 major spinners)
spin_bowlers = [
"Ravindra Jadeja","Kuldeep Yadav","Ravichandran Ashwin",
"Adam Zampa","Glenn Maxwell","Mitchell Santner",
"Rachin Ravindra","Ish Sodhi","Tabraiz Shamsi",
"Keshav Maharaj","Aiden Markram","Shakib Al Hasan",
"Mahedi Hasan","Mehidy Hasan Miraz","Rashid Khan",
"Mujeeb Ur Rahman","Mohammad Nabi","Adil Rashid",
"Moeen Ali","Liam Livingstone","Wanindu Hasaranga",
"Maheesh Theekshana","Dhananjaya de Silva"
]

# classify bowler type
wickets["bowler_type"] = wickets["bowler"].apply(
    lambda x: "Spin" if x in spin_bowlers else "Pace"
)

# %%
venue = "Arun Jaitley Stadium, Delhi"

data = wickets[wickets["venue"] == venue]

stats = data.groupby("bowler_type").size()

plt.figure(figsize=(6,4))
plt.bar(stats.index, stats.values)
plt.title("Spin vs Pace Wickets - Arun Jaitley Stadium, Delhi")
plt.xlabel("Bowler Type")
plt.ylabel("Total Wickets")
plt.show()

# %%
venue = "Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow"

data = wickets[wickets["venue"] == venue]

stats = data.groupby("bowler_type").size()

plt.figure(figsize=(6,4))
plt.bar(stats.index, stats.values)
plt.title("Spin vs Pace Wickets - Ekana Stadium, Lucknow")
plt.xlabel("Bowler Type")
plt.ylabel("Total Wickets")
plt.show()

# %%
venue = "Eden Gardens, Kolkata"

data = wickets[wickets["venue"] == venue]

stats = data.groupby("bowler_type").size()

plt.figure(figsize=(6,4))
plt.bar(stats.index, stats.values)
plt.title("Spin vs Pace Wickets - Eden Gardens, Kolkata")
plt.xlabel("Bowler Type")
plt.ylabel("Total Wickets")
plt.show()

# %%
venue = "Himachal Pradesh Cricket Association Stadium, Dharamsala"

data = wickets[wickets["venue"] == venue]

stats = data.groupby("bowler_type").size()

plt.figure(figsize=(6,4))
plt.bar(stats.index, stats.values)
plt.title("Spin vs Pace Wickets - Dharamsala")
plt.xlabel("Bowler Type")
plt.ylabel("Total Wickets")
plt.show()

# %%
venue = "M Chinnaswamy Stadium, Bengaluru"

data = wickets[wickets["venue"] == venue]

stats = data.groupby("bowler_type").size()

plt.figure(figsize=(6,4))
plt.bar(stats.index, stats.values)
plt.title("Spin vs Pace Wickets - Bengaluru")
plt.xlabel("Bowler Type")
plt.ylabel("Total Wickets")
plt.show()

# %%
venue = "MA Chidambaram Stadium, Chepauk, Chennai"

data = wickets[wickets["venue"] == venue]

stats = data.groupby("bowler_type").size()

plt.figure(figsize=(6,4))
plt.bar(stats.index, stats.values)
plt.title("Spin vs Pace Wickets - Chennai")
plt.xlabel("Bowler Type")
plt.ylabel("Total Wickets")
plt.show()

# %%
venue = "MA Chidambaram Stadium, Chepauk, Chennai"

data = wickets[wickets["venue"] == venue]

stats = data.groupby("bowler_type").size()

plt.figure(figsize=(6,4))
plt.bar(stats.index, stats.values)
plt.title("Spin vs Pace Wickets - Chennai")
plt.xlabel("Bowler Type")
plt.ylabel("Total Wickets")
plt.show()

# %%
venue = "Narendra Modi Stadium, Ahmedabad"

data = wickets[wickets["venue"] == venue]

stats = data.groupby("bowler_type").size()

plt.figure(figsize=(6,4))
plt.bar(stats.index, stats.values)
plt.title("Spin vs Pace Wickets - Ahmedabad")
plt.xlabel("Bowler Type")
plt.ylabel("Total Wickets")
plt.show()

# %%
venue = "Rajiv Gandhi International Stadium, Uppal, Hyderabad"

data = wickets[wickets["venue"] == venue]

stats = data.groupby("bowler_type").size()

plt.figure(figsize=(6,4))
plt.bar(stats.index, stats.values)
plt.title("Spin vs Pace Wickets - Hyderabad")
plt.xlabel("Bowler Type")
plt.ylabel("Total Wickets")
plt.show()

# %%
venue = "Wankhede Stadium, Mumbai"

data = wickets[wickets["venue"] == venue]

stats = data.groupby("bowler_type").size()

plt.figure(figsize=(6,4))
plt.bar(stats.index, stats.values)
plt.title("Spin vs Pace Wickets - Wankhede Stadium")
plt.xlabel("Bowler Type")
plt.ylabel("Total Wickets")
plt.show()

# %%
print("Insight – Pace vs Spin Bowling Across Venues")
print("The venue-wise analysis of wickets taken by spin bowlers and pace bowlers shows that fast bowlers claimed a significantly higher number of wickets compared to spinners across most stadiums during the ICC Men's ODI World Cup 2023. This pattern suggests that many pitches used in the tournament provided favorable conditions for pace bowlers, such as good bounce, seam movement, and assistance for swing bowling. Venues like Dharamsala, Wankhede Stadium, and Eden Gardens particularly showed a strong dominance of pace bowlers in wicket-taking. While Indian pitches are traditionally known for supporting spin bowling, the data from this tournament indicates that the pitch preparations and match conditions during the World Cup were relatively balanced or even slightly favorable to fast bowlers. Therefore, pace bowling played a crucial role in determining match outcomes across multiple venues during the tournament.")
# Out:
# Insight – Pace vs Spin Bowling Across Venues
# The venue-wise analysis of wickets taken by spin bowlers and pace bowlers shows that fast bowlers claimed a significantly higher number of wickets compared to spinners across most stadiums during the ICC Men's ODI World Cup 2023. This pattern suggests that many pitches used in the tournament provided favorable conditions for pace bowlers, such as good bounce, seam movement, and assistance for swing bowling. Venues like Dharamsala, Wankhede Stadium, and Eden Gardens particularly showed a strong dominance of pace bowlers in wicket-taking. While Indian pitches are traditionally known for supporting spin bowling, the data from this tournament indicates that the pitch preparations and match conditions during the World Cup were relatively balanced or even slightly favorable to fast bowlers. Therefore, pace bowling played a crucial role in determining match outcomes across multiple venues during the tournament.

# %%
batting_runs = df.groupby("batting_team")["runs_off_bat"].sum().sort_values(ascending=False)

print(batting_runs)
# Out:
# batting_team
# India           3038
# Australia       2945
# South Africa    2773
# New Zealand     2712
# Pakistan        2220
# England         2135
# Afghanistan     1990
# Bangladesh      1944
# Sri Lanka       1942
# Netherlands     1728
# Name: runs_off_bat, dtype: int64

# %%
import matplotlib.pyplot as plt

batting_runs.plot(kind="bar", figsize=(10,6))

plt.title("Total Runs by Team")
plt.xlabel("Team")
plt.ylabel("Runs Scored")

plt.show()

# %%
wickets = df[df["wicket_type"].notna()]

bowling_wickets = wickets.groupby("bowling_team").size().sort_values(ascending=False)

print(bowling_wickets)
# Out:
# bowling_team
# India           100
# Australia        93
# South Africa     89
# New Zealand      73
# England          69
# Pakistan         67
# Netherlands      66
# Afghanistan      61
# Sri Lanka        57
# Bangladesh       54
# dtype: int64

# %%
bowling_wickets.plot(kind="bar", figsize=(10,6))

plt.title("Total Wickets by Team")
plt.xlabel("Team")
plt.ylabel("Wickets Taken")

plt.show()

# %%
team_performance = pd.DataFrame({
    "Runs Scored": batting_runs,
    "Wickets Taken": bowling_wickets
})

print(team_performance)
# Out:
#               Runs Scored  Wickets Taken
# Afghanistan          1990             61
# Australia            2945             93
# Bangladesh           1944             54
# England              2135             69
# India                3038            100
# Netherlands          1728             66
# New Zealand          2712             73
# Pakistan             2220             67
# South Africa         2773             89
# Sri Lanka            1942             57

# %%
print("Insight – Team Consistency in Batting and Bowling")
print("The analysis of total runs scored and total wickets taken by each team helps identify the most consistent teams in the ICC Men's ODI World Cup 2023. Teams that scored a high number of runs while also taking a large number of wickets demonstrated balanced performance in both batting and bowling departments. Such teams were able to dominate matches by building competitive totals and restricting opponents effectively. This balanced performance indicates strong team composition and strategic gameplay, which contributed significantly to their success in the tournament.")
# Out:
# Insight – Team Consistency in Batting and Bowling
# The analysis of total runs scored and total wickets taken by each team helps identify the most consistent teams in the ICC Men's ODI World Cup 2023. Teams that scored a high number of runs while also taking a large number of wickets demonstrated balanced performance in both batting and bowling departments. Such teams were able to dominate matches by building competitive totals and restricting opponents effectively. This balanced performance indicates strong team composition and strategic gameplay, which contributed significantly to their success in the tournament.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("matches .csv")

# Identify win type
df["Bat First Win"] = df["winner_runs"] > 0
df["Chasing Win"] = df["winner_wickets"] > 0

venue_analysis = df.groupby("venue")[["Bat First Win","Chasing Win"]].sum()

plt.figure(figsize=(14,7))

venue_analysis.plot(
    kind="bar",
    color=["#1f77b4","#ff7f0e"]
)

plt.title("Batting First vs Chasing Wins by Venue", fontsize=16)
plt.xlabel("Venue", fontsize=12)
plt.ylabel("Number of Matches", fontsize=12)

plt.xticks(rotation=90)   # makes venue names vertical

plt.legend(["Bat First Win","Chasing Win"])

plt.tight_layout()
plt.style.use("seaborn-v0_8")
plt.show()
# Out:
# C:\Users\niles\AppData\Local\Temp\ipykernel_30964\4254810566.py:27: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
print("Venue Advantage: Batting First vs Chasing")
print("The venue-wise analysis of match outcomes reveals noticeable differences in the success of teams batting first versus chasing targets. Some venues such as Wankhede Stadium, Dharamsala Stadium, and Eden Gardens favored teams batting first, where defending totals resulted in more victories. In contrast, venues like MA Chidambaram Stadium (Chennai) and Narendra Modi Stadium (Ahmedabad) showed a higher number of successful run chases, indicating conditions that supported batting in the second innings. These variations suggest that pitch behavior, dew factor, and match conditions influenced the effectiveness of batting first or chasing across different stadiums during the ICC Men's ODI World Cup 2023.")
# Out:
# Venue Advantage: Batting First vs Chasing
# The venue-wise analysis of match outcomes reveals noticeable differences in the success of teams batting first versus chasing targets. Some venues such as Wankhede Stadium, Dharamsala Stadium, and Eden Gardens favored teams batting first, where defending totals resulted in more victories. In contrast, venues like MA Chidambaram Stadium (Chennai) and Narendra Modi Stadium (Ahmedabad) showed a higher number of successful run chases, indicating conditions that supported batting in the second innings. These variations suggest that pitch behavior, dew factor, and match conditions influenced the effectiveness of batting first or chasing across different stadiums during the ICC Men's ODI World Cup 2023.

# %%
points = pd.read_csv("points_table.csv")

points[["Team","Won","Lost","Net Run Rate"]].sort_values("Won", ascending=False)
# Out:
#            Team  Won  Lost  Net Run Rate
# 0         India    9     0         2.570
# 1  South Africa    7     2         1.261
# 2     Australia    7     2         0.841
# 3   New Zealand    5     4         0.743
# 4      Pakistan    4     5        -0.199
# 5   Afghanistan    4     5        -0.336
# 6       England    3     6        -0.572
# 7    Bangladesh    2     7        -1.087
# 8     Sri Lanka    2     7        -1.419
# 9   Netherlands    2     7        -1.825

# %%
df = pd.read_csv("deliveries.csv")

# %%
batting_runs = df.groupby("batting_team")["runs_off_bat"].sum().sort_values(ascending=False)

print(batting_runs)
# Out:
# batting_team
# India           3038
# Australia       2945
# South Africa    2773
# New Zealand     2712
# Pakistan        2220
# England         2135
# Afghanistan     1990
# Bangladesh      1944
# Sri Lanka       1942
# Netherlands     1728
# Name: runs_off_bat, dtype: int64

# %%
wickets = df[df["wicket_type"].notna()]

bowling_wickets = wickets.groupby("bowling_team").size().sort_values(ascending=False)

print(bowling_wickets)
# Out:
# bowling_team
# India           100
# Australia        93
# South Africa     89
# New Zealand      73
# England          69
# Pakistan         67
# Netherlands      66
# Afghanistan      61
# Sri Lanka        57
# Bangladesh       54
# dtype: int64

# %%
team_analysis = pd.DataFrame({
    "Runs Scored": batting_runs,
    "Wickets Taken": bowling_wickets
})

print(team_analysis)
# Out:
#               Runs Scored  Wickets Taken
# Afghanistan          1990             61
# Australia            2945             93
# Bangladesh           1944             54
# England              2135             69
# India                3038            100
# Netherlands          1728             66
# New Zealand          2712             73
# Pakistan             2220             67
# South Africa         2773             89
# Sri Lanka            1942             57

# %%
print("Team Performance Analysis – Australia")
print("The analysis reveals that Australia distinguished itself from other teams through consistent performances in both batting and bowling departments. The team maintained a strong balance between scoring competitive totals and effectively restricting opponents. Australia’s bowlers consistently took crucial wickets, while the batting lineup delivered stable and impactful performances across multiple matches. This balanced team composition, combined with strategic gameplay and consistency, played a key role in Australia’s success and ultimately led to their championship victory in the ICC Men's ODI World Cup 2023.")
# Out:
# Team Performance Analysis – Australia
# The analysis reveals that Australia distinguished itself from other teams through consistent performances in both batting and bowling departments. The team maintained a strong balance between scoring competitive totals and effectively restricting opponents. Australia’s bowlers consistently took crucial wickets, while the batting lineup delivered stable and impactful performances across multiple matches. This balanced team composition, combined with strategic gameplay and consistency, played a key role in Australia’s success and ultimately led to their championship victory in the ICC Men's ODI World Cup 2023.
